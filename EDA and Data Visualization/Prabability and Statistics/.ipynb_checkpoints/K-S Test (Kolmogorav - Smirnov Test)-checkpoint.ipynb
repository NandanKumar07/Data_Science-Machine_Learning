# %% [markdown]
# ### K-S Test For Similarity of Two Distributions

# %%
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# %%
# Generate a Gaussian random variable X
x = stats.norm.rvs(size = 1000)
sns.set_style('whitegrid')
sns.kdeplot(np.array(x), bw_method = 0.5)
plt.show()

# %%
stats.kstest(x, 'norm')
# Out:
# KstestResult(statistic=0.04240349014667805, pvalue=0.053295504965326534, statistic_location=-0.39776016913707146, statistic_sign=-1)

# %%
# Y ~ Conitnuous Uniform Distribution
y = np.random.uniform(0,1,10000)
sns.kdeplot(np.array(y), bw_method = 0.1)
plt.show()

# %%
stats.kstest(y, 'norm')
# Out:
# KstestResult(statistic=0.5001008990322546, pvalue=0.0, statistic_location=0.0002529163698286041, statistic_sign=-1)
